# %% [markdown]
# # if (sona) 1130 남편님을 요리조리 왔다갔다

# %%
import numpy as np
from skimage import io
import matplotlib.pyplot as plt

# %%
남편님 = io.imread('남편님.jpg') # 이미지 불러오기

# %%
type(남편님) #남편님 이미지 타입
# Out:
# numpy.ndarray

# %%
남편님.shape
# Out:
# (1440, 672, 3)

# %%
plt.imshow(남편님)

# %%
#남편님을 거꾸로 돌려볼까나
plt.imshow(남편님[::-1])

# %%
#남편님 좌우로 뒤집어보고
plt.imshow(남편님[:,::-1])

# %%
#귀여운 얼굴부분만 확대해서 보려면 
plt.imshow(남편님[70:400,200:450])

# %%
# 너무 확대되어서 위험하니 모자이크를 해줘야지
plt.imshow(남편님[70:400:10,200:450:10])
